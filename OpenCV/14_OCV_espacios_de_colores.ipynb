# %% [markdown]
# # 14_OCV_espacios_de_colores

# %% [markdown]
# # Espacios de colores

# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
def mostrar_imagen(title, imagen):
    imagen = cv2.cvtColor(imagen,cv2.COLOR_BGR2RGB)
    plt.imshow(imagen)
    plt.title(title)
    plt.grid(False)
    plt.show()

# %%
args = { "imagen": "stich.png"}

# %%
imagen = cv2.imread(args["imagen"])
cv2_imshow(imagen)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7FCD51E6ED10>
# -1

# %%
gray = cv2.cvtColor(imagen,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7FCD51E699D0>
# -1

# %%
hsv = cv2.cvtColor(imagen,cv2.COLOR_BGR2HSV)
cv2_imshow(hsv)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7FCD51E6F3D0>
# -1

# %%
lab = cv2.cvtColor(imagen,cv2.COLOR_BGR2LAB)
cv2_imshow(lab)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7FCD51E6FC10>
# -1
